# %% [markdown]
# # Taller de Principios de Química - Catálisis
#
# **Materia:** Principios de Química
#
# **Autor:** Juan Nicolás Martínez Franco

# %% [markdown]
# ## Tabla de contenido
#
# 1. **1. Introducción a la catálisis**
#    1.1. Definición de catálisis
#    1.2. Historia de la catálisis
#    1.3. Importancia de la catálisis en la industria y procesos biológicos
#    1.4. Diferencia entre catalizadores homogéneos, heterogéneos y biocatalizadores
#    1.5. Propiedades generales de un catalizador
#    1.6. Tipos de catálisis
#       1.6.1. Catálisis ácida
#       1.6.2. Catálisis básica
#       1.6.3. Catálisis metálica
#       1.6.4. Catálisis enzimática
#
# 2. **2. Bases preliminares**
#    2.1. Principios de la termodinámica aplicados a la catálisis
#    2.2. Energía de activación y su relación con la velocidad de reacción
#    2.3. Teoría de los complejos activados
#    2.4. Concepto de equilibrio químico en presencia de catalizadores
#    2.5. Principio de Le Chatelier aplicado a reacciones catalizadas
#    2.6. Factores que afectan la actividad catalítica
#
# 3. **3. Mecanismos de acción catalítica**
#    3.1. Mecanismos generales de acción catalítica
#    3.2. Teoría del complejo de transición y su relación con los mecanismos de reacción
#    3.3. Mecanismos de catálisis en sistemas homogéneos y heterogéneos
#    3.4. Catálisis por contacto o por adsorción
#    3.5. Ciclo de Langmuir–Hinshelwood
#    3.6. Catálisis enzimática: mecanismos específicos
#    3.7. Modelos de sitios activos y su interacción con los reactivos
#    3.8. Modelo llave–cerradura (Key–Lock)
#    3.9. Modelo de ajuste inducido
#
# 4. **4. Mecanismos de degradación catalítica**
#    4.1. Saturación
#    4.2. Envenenamiento
#    4.3. Bloqueo
#    4.4. Definición y tipos de degradación catalítica
#    4.5. Envenenamiento de catalizadores: mecanismos y causas
#    4.6. Sinterización de catalizadores: efectos en la actividad y selectividad
#    4.7. Desactivación por contaminación
#    4.8. Degradación en sistemas heterogéneos: análisis de la estructura superficial
#    4.9. Reacciones secundarias y su impacto en la vida útil del catalizador
#
# 5. **5. Regeneración y estrategias para prevenir la degradación catalítica**
#    5.1. Mecanismos de regeneración de catalizadores
#    5.2. Estrategias para prevenir o minimizar la degradación catalítica
#
# 6. **6. Aspectos avanzados y nuevas tendencias en catálisis**
#    6.1. Catálisis en la economía circular y sostenibilidad
#    6.2. Avances en catálisis de metales en forma de nanopartículas
#    6.3. Uso de catalizadores reciclables y regenerables
#
# 7. **7. Nuevas tendencias específicas en catálisis**
#    7.1. Catálisis computacional y modelado molecular
#    7.2. Evaluación catalítica de metales preciosos frente a metales base
#    7.3. Catálisis en condiciones extremas
#    7.4. Desarrollo de nuevos materiales catalíticos (nanotecnología)
#
# 8. **Referencias generales**

# %% [markdown]
# ## 1. Introducción a la catálisis

# %% [markdown]
# ### 1.1. Definición de catálisis
#
# La catálisis es el proceso mediante el cual una sustancia llamada catalizador aumenta la velocidad de una reacción química; además, su masa y composición no cambian a lo largo de la reacción, a diferencia de los reactivos (Fogler, 2016). El catalizador actúa disminuyendo la energía de activación, lo que permite que la reacción proceda más rápidamente o en condiciones más suaves (menor temperatura o presión).

# %% [markdown]
# ### 1.2. Historia de la catálisis
#
# La historia de la catálisis inicia desde lo ancestral hacia lo moderno; la palabra "catálisis" proviene del griego: significa "abajo" y "aflojar". En aquella época, la afinidad se conocía como una fuerza impulsora química, pero no se conocían, a nivel molecular, las velocidades de reacción. La catálisis, como herramienta para llevar a cabo reacciones, ya se había explotado mucho antes.
#
# La introducción del término se le atribuye a Berzelius en 1835, quien concluyó que, además de la "afinidad", operaba una nueva fuerza: la "fuerza catalítica" (Moulijn et al., 1993). Wilhelm Ostwald la definió científicamente en 1894 como la aceleración de reacciones. En el siglo XX se evidenciaron avances clave, como el proceso Haber-Bosch (amoníaco) y el catalizador de Wilkinson (1965), hasta los convertidores catalíticos para automóviles en la década de los 70, que revolucionaron el control de emisiones y la química industrial, convirtiéndose en una disciplina científica fundamental.

# %% [markdown]
# ### 1.3. Importancia de la catálisis en la industria y procesos biológicos
#
# La catálisis impulsa la sostenibilidad industrial (combustibles, plásticos, fármacos, fertilizantes) y la eficiencia de procesos clave como el refinamiento de petróleo y la producción de hidrógeno; mientras que, en biología, las enzimas (catalizadores biológicos) son esenciales para el metabolismo, la digestión y la producción de energía en todos los seres vivos, siendo la base de la vida misma.
#
# En la industria más del 90% de los procesos químicos industriales usan catalizadores en alguna etapa del proceso productivo, y en la biología todas las reacciones esenciales para la vida están catalizadas por enzimas, que permiten velocidades millones de veces mayores que sin catalizador (Cornils & Herrmann, 2017). Además, los catalizadores permiten procesos más limpios (menor energía, menos residuos), como los catalizadores automotrices para reducir NOx, CO y HC.

# %% [markdown]
# ### 1.4. Diferencia entre catalizadores homogéneos, heterogéneos y biocatalizadores
#
# Se considera catálisis homogénea aquella que comprende sistemas formados por una sola fase, es decir, los reactivos, productos y catalizadores se encuentran en la misma fase, la cual generalmente suele ser líquida. El catalizador se encuentra disperso uniformemente en el medio de reacción y la interacción entre los reactivos y el catalizador se ve más favorecida, obteniéndose velocidades de reacción más rápidas en comparación con la catálisis heterogénea. Como contrapartida, es más complicado separar/eliminar el catalizador del medio de reacción, lo que puede llevar un mayor coste con respecto a los procesos heterogéneos (AIMPLAS, 2024).
#
# La catálisis heterogénea tiene lugar cuando el catalizador se encuentra en una fase distinta a la de los reactantes y productos, generalmente sólido-líquido o sólido-gas. La reacción transcurre en la superficie del catalizador donde están presentes los centros activos. Por ello, cuanto menor es el tamaño de partícula del catalizador, mayor es el área superficial para una masa dada y mayor la actividad del catalizador (AIMPLAS, 2024).
#
# La catálisis enzimática los catalizadores empleados son enzimas, catalizadores biológicos que encontramos en la naturaleza y que comúnmente son de naturaleza proteica (polímeros de aminoácidos). La catálisis enzimática se puede llevar a cabo tanto de forma homogénea como heterogénea y se emplea en una gran cantidad de reacciones (hidrólisis, polimerizaciones por apertura de anillo, condensaciones, etc.). Una de las grandes ventajas de las enzimas es su elevada selectividad. Las enzimas inmovilizadas son fácilmente recuperables y reutilizables (AIMPLAS, 2024).
#
# Tabla 1.  Análisis comparativo entre catalizadores

# %% [markdown]
# ### 1.5. Propiedades generales de un catalizador
#
# Un catalizador debe cumplir (Fogler, 2016):
#
# - Aumentar la velocidad de la reacción.
# - No consumirse durante la reacción.
# - No modificar el equilibrio químico (solo acelera la llegada al equilibrio).
# - Presentar selectividad, permitiendo obtener productos deseados.
# - Tener estabilidad en las condiciones del proceso.
# - En catálisis heterogénea, debe tener gran área superficial activa.

# %% [markdown]
# ### 1.6. Tipos de catálisis
#
# Catálisis ácida: La catálisis ácida es un proceso químico donde un catalizador ácido acelera una reacción al donar un protón (H⁺) o aceptar un par de electrones, usando ácidos de Brønsted o Lewis para reacciones, por ejemplo, el uso de ácido sulfúrico en la esterificación (Facultad de Ingeniería Química – UNL, 2010).
#
# Catálisis básica: La catálisis básica es un proceso químico donde una base (como NaOH, KOH) acelera una reacción al aceptar protones o proporcionar un entorno alcalino, facilitando la formación o ruptura de enlaces, crucial en la transesterificación producción de biodiésel (Kilpatrick, 1954).
#
# Catálisis metálica: Los catalizadores metálicos se definen como metales, en particular metales de transición, que aceleran las reacciones químicas al proporcionar una superficie donde los reactivos pueden interactuar, a menudo soportados sobre óxidos u otros materiales para mejorar su actividad y selectividad. Su eficacia depende de factores como el área superficial del metal, el enlace químico con los reactivos y la estabilidad en las condiciones de reacción (Ross, 2019).
#
# Catálisis enzimática: La catálisis enzimática es un proceso en el que las enzimas actúan como catalizadores biológicos para acelerar las reacciones químicas, reduciendo la energía de activación sin consumirse en el proceso. Esto se logra mediante la unión del sustrato a un sitio activo específico en la enzima, donde se transforma en producto y es liberado, permitiendo que la enzima catalice otra reacción. Este proceso es fundamental para la vida y es muy eficiente y selectivo (Blanco & Blanco, 2022).

# %% [markdown]
# ## 2. Bases preliminares

# %% [markdown]
# ### 2.1. Principios de la termodinámica aplicados a la catálisis
#
# La catálisis no modifica la termodinámica de una reacción:
#
# - El cambio en la Energía Libre de Gibbs (ΔG), el cambio en la entalpía (ΔH) y la entropía ΔS permanecen iguales.
# - El catalizador no cambia el equilibrio químico, solo acelera la velocidad para alcanzarlo más rápido.
# - La reacción catalizada y la no catalizada tienen la misma energía libre de reacción y el mismo estado de equilibrio.
#
# Principios clave incluyen la Energía Libre de Gibbs, que determina la espontaneidad de la reacción, y el Principio de Sabatier, crucial en electrocatálisis para la fuerza de enlace ideal catalizador-reactivo.
#
# El efecto termodinámico clave es que un catalizador proporciona una vía alternativa de menor energía de activación; esto quiere decir que la presencia del catalizador actúa sobre la cinética, no sobre la termodinámica del sistema (Ooka et al., 2021).

# %% [markdown]
# ### 2.2. Energía de activación y su relación con la velocidad de reacción
#
# La energía de activación se define como la cantidad mínima de energía necesaria para iniciar una reacción química. Es un parámetro crucial que influye en la velocidad de reacción al controlar la probabilidad de que las moléculas reactivas colisionen con la energía suficiente para experimentar una transformación (Brewster, 2003).
#
# En otras palabras, la energía de activación (Ea) es la energía mínima requerida para que los reactivos formen productos.
#
# El catalizador disminuye la energía de activación, lo que incrementa la constante de velocidad (k) según la ecuación de Arrhenius:
#
# Una disminución en la energía de activación aumenta exponencialmente la velocidad.

# %% [markdown]
# ### 2.3. Teoría de los complejos activados
#
# La Teoría del Complejo Activado (o Teoría del Estado de Transición) explica que para que ocurra una reacción química los reactantes deben chocar y formar una estructura intermedia, antes de formar el producto, de muy alta energía y corta vida llamada complejo activado (o estado de transición). El catalizador facilita la formación de este complejo reduciendo su energía.
#
# Esta teoría proporciona una explicación para la velocidad de una reacción química, es decir, expresa la velocidad de reacción en términos del número de complejos activados (estructuras transicionales en el punto de energía máxima a lo largo de la ruta de reacción) que alcanzan el estado activado para formar los productos.
#
# De acuerdo con esta teoría (Eyring, 1935):
#
# - Las moléculas de reactivo forman una especie intermedia llamada complejo activado o estado de transición antes de formar el producto. Este complejo activado es una entidad con alta carga energética y no es aislable.
# - El complejo activado puede descomponerse para dar los productos o puede desintegrarse para devolver los reactivos.
# - La diferencia de energía entre los reactivos y el complejo activado se llama energía de activación.
# - La fracción de moléculas que tienen energía igual o mayor que la energía de activación puede cruzar la barrera energética y formar el producto. Esta fracción de moléculas está dada por la ley de distribución de Boltzmann.
#
# De acuerdo con esta teoría la velocidad depende de la concentración del complejo activado:
#
# donde,
#
# kB es la constante de Boltzmann
# T es la temperatura absoluta
# h es la constante de Planck
# ΔG* es el cambio de energía de Gibbs
# R es la constante universal de los gases

# %% [markdown]
# ### 2.4. Concepto de equilibrio químico en presencia de catalizadores
#
# Un catalizador es una sustancia que aumenta la velocidad de una reacción química al reducir la barrera de energía para que ocurra la reacción. Logra esto proporcionando una ruta alternativa para la reacción con una menor energía de activación. Sin embargo, es importante notar que un catalizador no afecta la posición del equilibrio químico. No cambia la constante de equilibrio ni la energía de los reactivos o productos.
#
# El catalizador ayuda a que la reacción alcance el equilibrio más rápido, no favorece más la reacción directa o la inversa. Por lo tanto, las concentraciones de los reactivos y productos en el equilibrio permanecen iguales, ya sea que se use un catalizador o no. La presencia de un catalizador no cambia la posición del equilibrio, únicamente acelera la obtención del equilibrio (Denbigh, 1981).

# %% [markdown]
# ### 2.5. Principio de Le Chatelier aplicado a reacciones catalizadas
#
# El Principio de Le Chatelier describe cómo un sistema en equilibrio reacciona a perturbaciones (cambios de temperatura, presión, concentración) desplazándose para contrarrestar el cambio, pero los catalizadores no afectan la posición del equilibrio, solo aceleran tanto la reacción directa como la inversa, permitiendo que el equilibrio se alcance más rápido y de forma más eficiente, sin modificar las cantidades finales de reactivos y productos.
#
# Ejemplo: Si una reacción exotérmica se cataliza, el catalizador no cambia el hecho de que el aumento de temperatura favorece la reacción inversa.

# %% [markdown]
# ### 2.6. Factores que afectan la actividad catalítica (temperatura, presión, concentración, etc.)
#
# Los factores clave que afectan la actividad catalítica de enzimas son la temperatura, el pH, la concentración de enzima y la concentración de sustrato, además de la presencia de inhibidores o activadores. Cada uno influye en la velocidad de reacción, siendo cruciales para que la enzima mantenga su estructura y su sitio activo, permitiendo la unión al sustrato y la catálisis eficiente, con puntos óptimos específicos para cada enzima.
#
# Temperatura:
#
# Bajas temperaturas: Reducen la energía cinética, disminuyendo colisiones enzima-sustrato y velocidad de reacción.
# Temperatura Óptima: Máxima actividad.
# Temperaturas Altas:  la enzima (cambian su forma), perdiendo función catalítica.
#
# pH:
#
# Cada enzima tiene un pH óptimo. Fuera de este rango, el pH altera cargas en el sitio activo, afectando la unión del sustrato y la actividad.
#
# Concentración de Enzima:
#
# Al aumentar la enzima, la velocidad de reacción aumenta linealmente, siempre que haya sustrato suficiente.
#
# Concentración de Sustrato:
#
# Aumentar el sustrato incrementa la velocidad inicialmente.
# Se alcanza un punto de saturación donde la velocidad se estabiliza, porque todas las enzimas están ocupadas.
#
# Inhibidores y Activadores:
#
# Inhibidores: Sustancias que disminuyen o detienen la actividad enzimática (ej., venenos, algunos fármacos).
# Activadores (Cofactores/Coenzimas): Iones metálicos o moléculas orgánicas (vitaminas) necesarios para que la enzima sea activa y funcione correctamente.
#
# Los catalizadores diferentes a las enzimas también se ven afectados por la temperatura, como se evidencia en la ecuación de Arrhenius, donde un incremento en la temperatura aumenta la constante de velocidad al reducir de manera efectiva la influencia de la energía de activación. Sin embargo, temperaturas demasiado altas pueden generar efectos negativos como sinterización, desactivación térmica o formación de coque, especialmente en catalizadores metálicos o soportados.
#
# Además, las velocidades de reacción comúnmente dependen de la concentración inicial del reactivo límite. En catálisis heterogénea, esta relación suele describirse mediante modelos como Langmuir–Hinshelwood o Eley–Rideal, donde la adsorción del reactivo en los sitios activos determina en gran medida la velocidad global. En el caso de reacciones en fase gaseosa, la cinética frecuentemente se expresa en función de la presión parcial de los compuestos reactivos, lo que implica que un aumento en la presión incrementa la disponibilidad de moléculas adsorbibles sobre la superficie del catalizador. Por ello, la presión en sistemas gaseosos influye de manera significativa en la actividad catalítica, modificando tanto la cobertura superficial como el equilibrio de adsorción–desorción.

# %% [markdown]
# # 3. MECANISMOS DE ACCIÓN CATALÍTICA

# %% [markdown]
# ## 3.1. Mecanismos generales de acción catalítica
#
# La catálisis consiste en acelerar una reacción química mediante la disminución de la energía de activación y la provisión de una ruta alternativa para que los reactivos se conviertan en productos. Desde el punto de vista molecular, el catalizador interactúa con las especies reaccionantes para formar intermediarios de menor energía, lo que facilita que las colisiones entre moléculas sean efectivas y se alcance el estado de transición en un intervalo de tiempo dado.
#
# En términos mecanísticos, el catalizador suele unirse de manera temporal a los reactivos formando complejos intermedios. Estos complejos se transforman a través de una serie de pasos elementales hasta generar los productos finales, tras lo cual el catalizador se regenera. De esta forma, aunque el catalizador participa en el mecanismo y puede cambiar de estado de oxidación, coordinación o conformación durante el ciclo catalítico, no se consume de forma permanente.
#
# Es importante resaltar que la acción catalítica solo afecta a la cinética de la reacción, es decir, a la velocidad con que se alcanza el equilibrio. La termodinámica global del sistema (energía libre, entalpía y entropía de reacción) permanece inalterada, de modo que la posición del equilibrio no se modifica: tanto la reacción directa como la inversa se ven aceleradas en la misma proporción.

# %% [markdown]
# ## 3.2. Teoría del complejo de transición y su relación con los mecanismos de reacción
#
# La teoría del complejo de transición, también llamada teoría del estado de transición, propone que toda reacción química progresa a través de un estado intermedio de alta energía llamado complejo activado o estado de transición. Este complejo se forma cuando los reactivos han absorbido suficiente energía para reorganizar sus enlaces, pero aún no se han convertido en productos.
#
# Este complejo activado se sitúa en la cima de la barrera de energía del perfil de reacción. Una vez formado, puede evolucionar en dos direcciones: hacia la formación de productos o hacia la regeneración de los reactivos iniciales. La probabilidad de que el complejo avance hacia productos está relacionada con la altura de la barrera de energía y con la distribución de energías de las moléculas en el sistema.
#
# La catálisis modifica el perfil energético reduciendo la altura de esta barrera, es decir, disminuyendo la energía de activación. Al hacerlo, se incrementa el número de moléculas que alcanzan el estado de transición a una temperatura dada, lo que se traduce en un aumento de la velocidad de reacción. En términos mecanísticos, el catalizador estabiliza el complejo de transición o genera complejos alternativos de menor energía, facilitando el avance de la reacción.

# %% [markdown]
# ## 3.3. Mecanismos de catálisis en sistemas homogéneos y heterogéneos
#
# En la catálisis homogénea, el catalizador y los reactivos se encuentran en la misma fase, usualmente en solución líquida. El mecanismo suele implicar la formación de complejos intermedios en solución, transferencia de grupos funcionales, cambios en el estado de oxidación del catalizador y posterior liberación de los productos, regenerándose la especie catalítica inicial.
#
# En la catálisis heterogénea, el catalizador es sólido y los reactivos se encuentran en fase gaseosa o líquida. En este caso, el mecanismo incluye etapas de adsorción de reactivos sobre la superficie del sólido, reacción en sitios activos y desorción de los productos. La naturaleza y distribución de estos sitios activos, así como la estructura superficial del material, resultan determinantes para la actividad y selectividad global del sistema.
#
# En ambos casos, el catalizador participa en el mecanismo sin consumirse permanentemente, ofreciendo una ruta de reacción alternativa con menor energía de activación. La elección entre un sistema homogéneo u heterogéneo depende de consideraciones como facilidad de separación, estabilidad, selectividad y condiciones de operación.

# %% [markdown]
# ## 3.4. Catálisis por contacto o por adsorción
#
# La catálisis por contacto es característica de sistemas heterogéneos, en los que la reacción tiene lugar sobre la superficie de un sólido. El mecanismo general implica: (i) difusión de los reactivos hacia la superficie del catalizador, (ii) adsorción de las moléculas en los sitios activos, (iii) reacción química entre las especies adsorbidas y (iv) desorción de los productos formados.
#
# La naturaleza de la adsorción puede ser física (por fuerzas de Van der Waals) o química (mediante formación de enlaces químicos). La quimisorción suele ser más fuerte y específica, y está estrechamente relacionada con la actividad catalítica. La estructura superficial, el tamaño de partícula, la porosidad y la presencia de defectos o sitios coordinativamente insaturados influyen de manera decisiva en la eficiencia del proceso.
#
# La especificidad de los sitios activos determina la selectividad de la reacción: ciertos sitios pueden favorecer la ruptura de enlaces particulares o la formación de productos específicos. Por ello, el diseño de catalizadores porosos con alta área superficial y distribución adecuada de sitios activos es esencial en catálisis por contacto.

# %% [markdown]
# ## 3.5. Ciclo de Langmuir–Hinshelwood
#
# El mecanismo de Langmuir–Hinshelwood describe reacciones en las que dos reactivos adsorbidos sobre la superficie de un catalizador heterogéneo reaccionan entre sí. Según este modelo, ambos reactivos deben primero adsorberse en los sitios activos del sólido, alcanzar una cobertura superficial determinada y posteriormente reaccionar formando productos que se desorben de la superficie.
#
# En este modelo, la velocidad de reacción depende de la cobertura de la superficie por las especies adsorbidas y de la cinética elemental de la reacción entre ellas. Generalmente se asume que la adsorción sigue una isoterma de Langmuir, donde la fracción de superficie cubierta está relacionada con la presión o concentración de los reactivos en la fase fluida.
#
# La formulación de este mecanismo permite derivar ecuaciones de velocidad que relacionan la tasa de reacción con las presiones parciales o concentraciones de los reactivos, así como con las constantes de adsorción y desorción. Estas expresiones son ampliamente utilizadas para modelar reacciones en procesos industriales como la hidrogenación, la oxidación catalítica y la síntesis de amoníaco.

# %% [markdown]
# ## 3.6. Catálisis enzimática: mecanismos específicos
#
# En la catálisis enzimática, las enzimas actúan como catalizadores biológicos altamente especializados, capaces de acelerar reacciones específicas con una especificidad y eficiencia muy elevadas. El mecanismo general incluye la unión del sustrato al sitio activo de la enzima, la formación de un complejo enzima–sustrato, la transformación química hacia el estado de transición y, finalmente, la liberación del producto y la regeneración de la enzima libre.
#
# El sitio activo suele estar formado por un conjunto de residuos de aminoácidos que generan un entorno geométrico y electrónico adecuado para estabilizar el estado de transición y dirigir la reacción por una ruta concreta. A menudo se requiere la presencia de cofactores metálicos o coenzimas orgánicas que participan transitoriamente en la transformación química.
#
# Modelos cinéticos como el de Michaelis–Menten describen la dependencia de la velocidad inicial de reacción con la concentración de sustrato, introduciendo parámetros característicos como la constante de Michaelis ($K_m$) y la velocidad máxima ($V_{max}$). Estos parámetros permiten cuantificar la afinidad de la enzima por el sustrato y su eficiencia catalítica, aportando información clave para el diseño de procesos biotecnológicos.

# %% [markdown]
# ## 3.7. Modelos de sitios activos y su interacción con los reactivos
#
# La actividad catalítica se asocia a sitios activos específicos, que son regiones particulares de la superficie del catalizador en las que se lleva a cabo la reacción. En catalizadores heterogéneos, estos sitios pueden corresponder a átomos expuestos en bordes, esquinas, defectos cristalinos, vacancias u otros elementos estructurales con coordinación insaturada.
#
# La fuerza de adsorción, la geometría local y el entorno electrónico de estos sitios determinan la forma en que los reactivos se coordinan y reaccionan. Por ejemplo, una adsorción demasiado débil no permite la activación del reactivo, mientras que una adsorción excesivamente fuerte dificulta la desorción de los productos, reduciendo la actividad global, de acuerdo con el principio de Sabatier.
#
# El diseño racional de catalizadores busca optimizar estos sitios activos mediante el control del tamaño de partícula, la composición (monometálica, bimetálica o de aleaciones complejas), la naturaleza del soporte y la introducción de promotores o modificadores. La caracterización avanzada (microscopía electrónica, espectroscopías in situ, técnicas de difracción) permite correlacionar la estructura de los sitios con el desempeño catalítico.

# %% [markdown]
# ## 3.8. Key–Lock
#
# El modelo llave–cerradura (Key–Lock) propuesto por Emil Fischer sugiere que la especificidad enzimática se basa en una complementariedad rígida entre el sustrato y el sitio activo de la enzima. Según este modelo, la forma del sitio activo es exactamente complementaria a la del sustrato, de manera análoga a como una llave encaja en una cerradura.
#
# Bajo esta visión, solo moléculas con la geometría adecuada pueden unirse correctamente a la enzima y ser transformadas en productos. Este modelo explica de manera cualitativa la alta selectividad observada en muchas enzimas, ya que pequeñas variaciones en la estructura del sustrato pueden impedir la unión eficaz.
#
# Sin embargo, el modelo llave–cerradura no contempla los cambios conformacionales que muchas enzimas experimentan durante el proceso catalítico. Estudios posteriores han mostrado que los sitios activos suelen ser flexibles y que la unión del sustrato puede inducir ajustes estructurales significativos.

# %% [markdown]
# ## 3.9. Modelo de ajuste inducido
#
# El modelo de ajuste inducido, propuesto por Daniel Koshland, amplía la idea de Fischer al considerar que el sitio activo de la enzima es flexible. Según este modelo, la unión del sustrato induce cambios conformacionales en la enzima que ajustan el sitio activo para envolver al sustrato de manera más eficiente, estabilizando el estado de transición.
#
# En este caso, el sitio activo no es totalmente complementario al sustrato antes de la unión; la complementariedad se genera durante el proceso de reconocimiento y anclaje. Este comportamiento dinámico explica mejor la elevada eficiencia y especificidad de muchas enzimas, así como la posibilidad de que distintas moléculas, con estructuras similares, puedan inducir diferentes conformaciones y niveles de actividad.
#
# Este modelo también ayuda a entender fenómenos de regulación alostérica, donde la unión de moléculas efectoras en sitios distintos al activo modifica la conformación y la actividad catalítica de la enzima.

# %% [markdown]
# ## Referencias
#
# - Petrucci, R., Herring, F., Madura, J. & Bissonnette, C. (2011). *Química General*. 11ª ed. Pearson.
# - Fogler, H. S. (2016). *Elementos de Ingeniería de las Reacciones Químicas*. 5ª ed. Pearson.

# %% [markdown]
# ## 4. Mecanismos de degradación catalítica

# %% [markdown]
# ### 4.1. Saturación
#
# La saturación ocurre cuando todos los sitios activos del catalizador están ocupados por reactivos o intermediarios. En este punto, aumentar la concentración de reactivo no incrementa la velocidad (Cornish-Bowden, 2012).
#
# En catálisis enzimática se relaciona con la constante Km (modelo de Michaelis-Menten), donde la velocidad llega a un valor Vmáx.

# %% [markdown]
# ### 4.2. Envenenamiento
#
# El envenenamiento es la pérdida de actividad catalítica debido a la adsorción irreversible o fuertemente unida de especies que bloquean los sitios activos (Bartholomew, 2001).
#
# Tipos de venenos comunes
#
# Azufre (S): envenena catalizadores metálicos como Ni o Pt.
# Fósforo (P): afecta catalizadores de cracking.
# Compuestos orgánicos pesados, coque o halógenos.
#
# El veneno reduce la actividad porque los reactivos no pueden adsorberse.

# %% [markdown]
# ### 4.3. Bloqueo
#
# El bloqueo ocurre cuando productos, impurezas o depósitos temporales se fijan sobre el catalizador impidiendo la adsorción. A diferencia del envenenamiento, el bloqueo suele ser reversible y no necesariamente implica cambios estructurales permanentes. Por ejemplo, agua adsorbida sobre un catalizador básico puede bloquear sitios activos.

# %% [markdown]
# ### 4.4. Definición y tipos de degradación catalítica
#
# La degradación catalítica es la pérdida parcial o total de la actividad, selectividad o estabilidad de un catalizador durante su uso. Puede deberse a factores químicos, térmicos, estructurales o ambientales (Bartholomew & Farrauto, 2006).
#
# Principales tipos de degradación catalítica
#
# Envenenamiento: Ocurre cuando especies químicas externas (impurezas como S, P, Cl, metales pesados) se adsorben fuertemente sobre los sitios activos, bloqueándolos de manera irreversible o semirreversible.
# Fouling o bloqueo (ensuciamiento): Consiste en la deposición de productos pesados, polímeros, compuestos orgánicos o agua que obstruyen los poros o cubren temporalmente los sitios activos. Suele ser reversible.
# Formación de coque (carbonización): Carbono o coque se forma por reacciones secundarias y se deposita sobre la superficie, disminuyendo la accesibilidad a los sitios activos.
# Sinterización (aglomeración): A altas temperaturas, las partículas del catalizador (generalmente metales) experimentan crecimiento cristalino, disminuyendo el área superficial y la cantidad de sitios activos.
# Envejecimiento térmico: Cambios físicos o estructurales por temperaturas prolongadas: colapso de poros, pérdida de superficie específica o cambios en la fase cristalina del soporte.
# Pérdida del soporte o degradación del soporte: El soporte (como alúmina o zeolitas) puede desintegrarse, fracturarse o perder acidez/superficie por exposición a vapor, presión elevada o contaminantes.
# Lixiviación (disolución): Ocurre cuando el metal activo o promotores se disuelven en el medio de reacción (común en catálisis homogénea o líquida).
# Corrosión o oxidación no deseada: Algunos catalizadores metálicos pueden oxidarse, sulfatizarse o clorarse, alterando la forma activa del metal.

# %% [markdown]
# ### 4.5. Envenenamiento de catalizadores: mecanismos y causas
#
# Envenenamiento de catalizadores: mecanismos y causas (Bartholomew, 2001)
#
# Mecanismos principales
#
# Quimisorción fuerte de impurezas desactiva sitios activos.
# Formación de complejos estables entre metal y veneno. Ejemplo Ni–S.
# Reacciones secundarias que generan especies que bloquean la superficie.
#
# Causas
#
# Impurezas en la alimentación (S, N, halógenos).
# Productos secundarios que se depositan.
# Condiciones incorrectas de operación.

# %% [markdown]
# ### 4.6. Sinterización de catalizadores: efectos en la actividad y selectividad
#
# La sinterización es un proceso de degradación catalítica que ocurre principalmente a altas temperaturas, en el cual las partículas activas del catalizador (especialmente metales dispersos sobre un soporte) experimentan crecimiento, aglomeración o coalescencia. Como consecuencia, disminuye la superficie activa disponible, lo que afecta directamente la capacidad del catalizador para adsorber reactivos y facilitar reacciones químicas (Bartholomew, 2001).
#
# Mecanismo general de sinterización: La sinterización ocurre por dos rutas principales:
#
# Migración superficial y coalescencia: Las partículas metálicas pequeñas se desplazan a lo largo de la superficie del soporte y se unen entre sí, formando partículas más grandes.
# Crecimiento por difusión en volumen: Los átomos del metal se difunden hacia partículas cercanas, haciendo que unas crezcan a expensas de otras (proceso de ripening u Ostwald ripening).
#
# Estos fenómenos se aceleran cuando el catalizador está expuesto a temperaturas cercanas al punto de fusión reducido del metal soportado, presencia de vapor de agua, atmósferas oxidantes y/o fluctuaciones térmicas rápidas.
#
# Efectos sobre la actividad catalítica
#
# Disminución del área superficial metálica: Las partículas más grandes tienen menor superficie específica, reduciendo el número de sitios activos disponibles.
# Menor dispersión del metal: La actividad de muchos catalizadores depende de tener partículas muy pequeñas y bien dispersas; la sinterización destruye esa estructura.
# Pérdida de sitios activos específicos: Algunos sitios catalíticos solo existen en bordes o esquinas de partículas pequeñas. Al formarse partículas grandes, estos sitios desaparecen.
# El resultado final es una pérdida significativa de actividad, incluso cuando la composición química del catalizador no cambia.
#
# Efectos sobre la selectividad
#
# Cambia la geometría de los sitios activos, favoreciendo rutas de reacción distintas.
# Las partículas grandes tienden a promover reacciones menos selectivas, como deshidrogenación excesiva o craqueo no deseado.
# La reducción de la accesibilidad a poros o sitios específicos puede impedir la formación del producto deseado y favorecer subproductos.
# Esto es especialmente crítico en procesos donde la selectividad depende de la dispersión metálica, como hidrogenaciones, oxidaciones parciales o síntesis Fischer–Tropsch.

# %% [markdown]
# ### 4.7. Desactivación por contaminación
#
# La desactivación por contaminación ocurre cuando especies externas, generalmente impurezas presentes en las corrientes de alimentación o productos secundarios generados durante la reacción, se depositan, adsorben o reaccionan con los sitios activos del catalizador, provocando una pérdida parcial o total de actividad. Este es uno de los mecanismos más comunes de degradación, especialmente en procesos industriales de hidrotratamiento, reformado catalítico, cracking y reacciones de oxidación (Romero et al., 2020).
#
# Depósitos de carbón o coque
#
# Se forma por reacciones secundarias como deshidrogenación o polimerización.
# Bloquea poros y sitios activos.
# Es uno de los problemas más comunes en cracking catalítico y reformado.
#
# Contaminación por azufre
#
# Azufre forma enlaces fuertes con metales de transición.
# Incluso concentraciones ppm pueden causar desactivación severa.
#
# Otras formas de contaminación
#
# Además del azufre y el carbono, pueden causar contaminación:
# Fósforo, que neutraliza sitios ácidos en soportes como la alúmina.
# Halógenos (Cl, F), que producen corrosión y desactivación química.
# Metales pesados (As, Pb, Hg), que forman compuestos estables con los sitios activos.
# Siloxanos en biogás, que generan sílice amorfa sobre el catalizador.
# Agua, en el caso de catalizadores muy sensibles, bloqueando temporalmente los sitios activos.

# %% [markdown]
# ### 4.8. Degradación en sistemas heterogéneos: análisis de la estructura superficial
#
# Degradación en sistemas heterogéneos: análisis de la estructura superficial)
#
# La actividad catalítica en sistemas heterogéneos depende fuertemente de la estructura superficial del catalizador, ya que las reacciones ocurren en los sitios activos localizados en la superficie externa o en los poros accesibles del material. Por ello, cualquier cambio físico, químico o estructural en esta superficie afecta directamente la actividad, selectividad y estabilidad del catalizador (Somorjai & Li, 2010).
#
# La degradación en estos sistemas ocurre cuando la superficie del catalizador experimenta modificaciones que reducen la cantidad o disponibilidad de sitios activos. Entre los cambios más comunes se encuentran:
#
# a. Pérdida de área superficial activa
#
# El colapso de poros o la reducción de la superficie específica del soporte (por ejemplo, alúmina, sílice, zeolitas) disminuye el número de sitios activos accesibles para los reactivos. Esto suele ocurrir por exposición a altas temperaturas, presencia de vapor de agua o sinterización del soporte o del metal.
#
# b. Bloqueo y obstrucción de poros
#
# Depósitos de coque, sales metálicas, compuestos orgánicos pesados o contaminantes inorgánicos pueden obstruir las entradas o canales internos del catalizador. Esto reduce la difusión de reactivos hacia los sitios activos y genera limitaciones intraparticulares.
#
# c. Modificación química de la superficie
#
# Reacción de contaminantes como azufre (S), fósforo (P), halógenos, metales pesados, siloxanos; estos compuestos pueden reaccionar con el metal activo o con los sitios ácidos/básicos del soporte, alterando su naturaleza química y provocando envenenamiento irreversible.
#
# d. Cambios en la forma o fase del metal
#
# En catalizadores metálicos, transformaciones como: oxidación o reducción no deseada, formación de carburos o sulfuros y pérdida de dispersión metálica, modifican la estructura de los sitios activos. Estos cambios afectan directamente las rutas de reacción y la selectividad del proceso.
#
# e. Reestructuración superficial inducida por condiciones de reacción
#
# Fluctuaciones drásticas de temperatura, presiones elevadas o atmósferas reactivas pueden reconfigurar la superficie del catalizador. Esto incluye migración de átomos, redistribución de fases, aparición de defectos y pérdida de sitios activos específicos como bordes o esquinas.
#
# Consecuencias generales de la degradación superficial
#
# Disminución progresiva de la actividad catalítica.
# Cambios en la selectividad, debido a la alteración del tipo y distribución de sitios activos.
# Aumento de resistencias difusionales internas.
# Reducción de la vida útil del catalizador.
# Necesidad de regeneración o reemplazo del material.
#
# En conjunto, estos procesos hacen que la degradación superficial sea una de las causas más críticas de desactivación en la catálisis heterogénea.

# %% [markdown]
# ### 4.9. Reacciones secundarias y su impacto en la vida útil del catalizador
#
# Las reacciones secundarias son procesos no deseados que ocurren de manera paralela o consecutiva a la reacción principal y que pueden afectar de forma significativa la vida útil del catalizador. Estas reacciones generan subproductos o intermediarios que provocan desactivación, ya sea por la formación de coque y depósitos carbonosos que bloquean poros y cubren sitios activos, o por la producción de especies inhibidoras que compiten con los reactivos por la superficie del catalizador y reducen su actividad.
#
# En algunos casos, las reacciones secundarias pueden inducir transformaciones no deseadas en la fase activa como oxidación, sulfatación, cloración o formación de carburos, alterando la estructura superficial y disminuyendo tanto la actividad como la selectividad del sistema catalítico (Bartholomew, 2001). Además, estas reacciones pueden deteriorar el soporte, causando pérdida de acidez, colapso de poros o formación de depósitos inorgánicos que comprometen la accesibilidad a los sitios activos.
#
# En conjunto, estos efectos reducen la estabilidad operativa, incrementan la frecuencia de regeneración y disminuyen la vida útil del catalizador, lo que representa un reto importante en procesos heterogéneos industriales.

# %% [markdown]
# ## 5. Regeneración y estrategias para prevenir o minimizar la degradación catalítica

# %% [markdown]
# ### 5.1. Mecanismos de regeneración de catalizadores
#
# La regeneración de catalizadores es el conjunto de procedimientos destinados a restaurar parcial o totalmente la actividad y selectividad de un catalizador que se ha desactivado durante la operación. Debido a que la degradación puede originarse por diferentes mecanismos, la estrategia de regeneración debe ajustarse al tipo de desactivación predominante y a las propiedades del material catalítico. En general, los procesos industriales combinan técnicas térmicas, químicas u oxidativas para remover depósitos, reactivar fases metálicas o recuperar la estructura superficial del catalizador (Hatta et al., 2023).
#
# La regeneración térmica es uno de los métodos más utilizados y consiste en calentar el catalizador bajo atmósferas controladas con el fin de eliminar depósitos volátiles o descomponer material orgánico acumulado. Cuando la desactivación se debe a la formación de coque, suele emplearse regeneración oxidativa, donde se introduce aire u oxígeno en cantidades cuidadosamente reguladas para quemar el carbono sin causar daños térmicos o sinterización.
#
# Por su parte, la regeneración química implica el uso de agentes reductores, solubles o reactivos (como hidrógeno, soluciones ácidas o básicas) capaces de remover contaminantes específicos, re-reducir óxidos metálicos o redispersar especies activas. En catalizadores metálicos soportados, las regeneraciones reductoras con H₂ permiten restaurar la fase activa después de oxidaciones o sulfataciones indeseadas.
#
# En ciertos casos, la desactivación implica cambios estructurales profundos, por lo que es necesario recurrir a regeneraciones combinadas, o incluso a tratamientos de reimpregnación o reactivación del soporte. Algunos mecanismos como la sinterización severa o la pérdida irreversible de sitios activos solo pueden mitigarse parcialmente, limitando la eficiencia de la regeneración y reduciendo la vida útil total del catalizador. Por esta razón, la selección del método apropiado y el control cuidadoso de las condiciones de regeneración son fundamentales para maximizar la estabilidad operativa y extender la utilidad industrial del catalizador (Bartholomew & Farrauto, 2006).

# %% [markdown]
# ### 5.2. Estrategias para prevenir o minimizar la degradación catalítica
#
# La prevención de la degradación catalítica es fundamental para prolongar la vida útil de los catalizadores y mantener la eficiencia, actividad y selectividad de los procesos industriales. Debido a que los mecanismos de desactivación pueden ser térmicos, químicos, estructurales o difusionales, las estrategias de prevención deben abordar tanto las condiciones de operación como las características fisicoquímicas del catalizador.
#
# En primer lugar, el control adecuado de temperatura y presión es esencial, ya que temperaturas excesivas pueden provocar sinterización, colapso de poros y desactivación térmica, mientras que presiones inapropiadas pueden favorecer reacciones secundarias o depósitos indeseados. También se deben evitar fluctuaciones térmicas bruscas, que aceleran procesos de reestructuración superficial y degradación del soporte.
#
# Otra estrategia fundamental consiste en minimizar la presencia de impurezas en las corrientes de alimentación. Para ello se aplican procesos de pretratamiento, como desulfurización, deshalogenación, filtración, hidrogenación o eliminación de metales pesados, que reducen la probabilidad de envenenamiento. De igual manera, la eliminación de partículas sólidas y aerosoles evita el bloqueo de poros y depósitos de coque o material inorgánico.
#
# En cuanto al diseño del catalizador, la incorporación de promotores y estabilizantes puede incrementar la resistencia a la sinterización, mejorar la dispersión metálica y aumentar la estabilidad térmica. El uso de soportes altamente resistentes también contribuye a mantener la integridad estructural bajo condiciones severas. En sistemas heterogéneos, mantener una adecuada distribución de flujo dentro del reactor evita puntos calientes y zonas de sobrecarga que aceleran la degradación local del material.
#
# Finalmente, la implementación periódica de ciclos de regeneración controlada ayuda a remover coque, reactivar metales o restaurar parcialmente la estructura catalítica antes de que la degradación sea irreversible. Estas regeneraciones programadas se integran como parte de la operación normal para garantizar que el catalizador mantenga su rendimiento óptimo durante el mayor tiempo posible.

# %% [markdown]
# ## 6. Aspectos avanzados y nuevas tendencias en catálisis

# %% [markdown]
# ### 6.1. Catálisis en la economía circular y sostenibilidad
#
# La economía circular busca reducir el uso de recursos primarios, minimizar residuos y reutilizar materiales. En este contexto, la catálisis juega un papel central al permitir:
#
# procesos más limpios que disminuyen emisiones y consumo energético,
# valorización de residuos, como biomasa, plásticos, aceites usados y CO₂,
# ciclos cerrados de materiales, gracias a catalizadores regenerables o reciclables,
# producción verde de combustibles y productos químicos mediante rutas catalíticas alternativas.
#
# Ejemplos relevantes incluyen la hidrogenación de CO₂ a combustibles sintéticos, la pirólisis catalítica de residuos plásticos y la conversión catalítica de biomasa a compuestos plataforma como HMF, furfural o bioalcoholes.

# %% [markdown]
# ### 6.2. Avances en catálisis de metales en forma de nanopartículas
#
# El desarrollo de nanopartículas metálicas ha revolucionado la catálisis heterogénea, debido a su alta relación superficie-volumen y a la presencia de sitios activos altamente expuestos (Del Rocío Redón de la Fuente, 2016). Entre los avances más destacados se encuentran:
#
# síntesis controlada de nanopartículas con tamaños y morfologías específicas,
# nanocatalizadores soportados, que exhiben mejor dispersión y estabilidad,
# uso de nanoaleaciones y bimetales con efectos sinérgicos,
# mejoras en selectividad, gracias a la ingeniería de facetas, bordes y defectos superficiales.
#
# Estos nanomateriales han demostrado un rendimiento superior en hidrogenación, oxidación, reformado, electrocatálisis y producción de energía limpia, como en celdas de combustible y electrólisis.

# %% [markdown]
# ### 6.3. Uso de catalizadores reciclables y regenerables
#
# Una de las áreas con mayor crecimiento es el desarrollo de catalizadores que puedan reciclarse, regenerarse y reutilizarse sin perder actividad. Esto incluye (Guibelondo, 2025):
#
# catalizadores heterogéneos robustos, diseñados para múltiples ciclos de operación,
# catalizadores magnéticos, que pueden separarse fácilmente mediante campos magnéticos,
# polímeros catalíticos y organocatalizadores recuperables por extracción,
# sistemas híbridos orgánico–inorgánicos con estabilidad mejorada.
#
# Además, la regeneración avanzada combina técnicas térmicas, reductoras, oxidativas y químicas para restaurar la estructura activa. Esto reduce costos operativos y disminuye el impacto ambiental, favoreciendo procesos industriales más sostenibles.

# %% [markdown]
# ## 7. Nuevas tendencias específicas en catálisis

# %% [markdown]
# ### 7.1 Catálisis computacional y modelado molecular
#
# La catálisis computacional emplea métodos de química cuántica, como teoría del funcional de la densidad (DFT), dinámica molecular y modelos de estructura electrónica, para estudiar la interacción entre reactivos y catalizadores a nivel atómico. Mediante estos cálculos es posible determinar energías de adsorción, estados de transición, rutas de reacción y perfiles de energía.
#
# Gracias al modelado molecular es posible predecir la reactividad de superficies, optimizar composiciones y geometrías de catalizadores, y explorar miles de formulaciones de manera virtual antes de sintetizarlas experimentalmente. Esto reduce ensayos experimentales y acelera la innovación en el diseño de nuevos materiales catalíticos.

# %% [markdown]
# ### 7.2 Evaluación catalítica de metales preciosos frente a metales base
#
# Los metales preciosos como Pt, Pd, Rh y Au presentan alta actividad catalítica y una fuerte resistencia a la oxidación, por lo que se han utilizado extensamente en reacciones de hidrogenación, oxidación selectiva y conversión de gases contaminantes. Sin embargo, su elevado costo y limitada disponibilidad impulsan la búsqueda de alternativas más económicas.
#
# Los metales base (Ni, Fe, Cu, Co) son más económicos y abundantes, y pueden mostrar una actividad comparable bajo condiciones adecuadas de soporte, dispersión y promoción. El desarrollo de aleaciones, bimetales y materiales de alto índice de superficie ha permitido acercar el rendimiento de estos metales base al de los metales preciosos, reduciendo costos y mejorando la sostenibilidad en catálisis.

# %% [markdown]
# ### 7.3 Catálisis en condiciones extremas
#
# Muchos procesos industriales se llevan a cabo bajo condiciones extremas de temperatura, presión o composición de la corriente de alimentación, lo que exige catalizadores altamente estables. Un ejemplo emblemático es el proceso Haber–Bosch, que opera a alta presión y temperatura para sintetizar amoníaco a partir de N₂ y H₂.
#
# El estudio de la catálisis en estos regímenes exige materiales resistentes a la sinterización, la corrosión, la formación de coque y la lixiviación. El diseño de soportes de alta estabilidad térmica, estructuras jerárquicas de poros y recubrimientos protectores es esencial para mantener el desempeño catalítico a largo plazo en condiciones severas.
#
# La comprensión de los mecanismos de degradación bajo estas condiciones extremas guía el desarrollo de catalizadores de nueva generación, capaces de operar de manera eficiente y segura en procesos intensivos, en favor de procesos eficientes y ambientalmente responsables.

# %% [markdown]
# ### 7.4 Desarrollo de nuevos materiales catalíticos (nanotecnología)
#
# La nanotecnología permite diseñar catalizadores con control fino sobre tamaño, forma, composición y estructura electrónica. Mediante nanopartículas, nanocables, nanocáscaras y materiales de porosidad ordenada, es posible ajustar las propiedades de adsorción y activación de reactivos, mejorando tanto la actividad como la selectividad de procesos catalíticos.
#
# El uso de dopantes, soportes funcionalizados o métodos de encapsulamiento contribuye a estabilizar las fases activas y prevenir la sinterización. Estos enfoques, combinados con herramientas de caracterización avanzada y simulaciones computacionales, hacen de la nanotecnología una de las áreas más dinámicas y avanzadas de la catálisis moderna.

# %% [markdown]
# ### Referencias
#
# - Fogler, H. S. *Elements of Chemical Reaction Engineering*. Pearson.
# - Masel, R. *Chemical Kinetics and Catalysis*. Wiley.
# - Somorjai, G. & Li, Y. *Introduction to Surface Chemistry and Catalysis*. Wiley.
# - Nørskov, J. et al. (2014). *Toward theoretical design of catalytic materials*. Nature Chemistry.
# - Chorkendorff, I. & Niemantsverdriet, H. *Concepts of Modern Catalysis and Kinetics*. Elsevier.

# %% [markdown]
# ## Referencias generales
#
# - Fogler, H. S. (2016). Elements of Chemical Reaction Engineering (5th ed.). Pearson.
# - Moulijn, J., Leeuwen, V. P., Santen, V. R., Moulijn, V. J., & Santen, R. (1993). Chapter 1 History of catalysis. Studies in Surface Science and Catalysis (pp. 3-21). https://doi.org/10.1016/s0167-2991(08)63805-7
# - Cornils, B., & Herrmann, W. A. (2017). Applied Homogeneous Catalysis with Organometallic Compounds.
# - AIMPLAS. (2024). Catálisis - AIMPLAS. https://www.aimplas.es/tecnologias/catalisis/
# - Facultad de Ingeniería Química – UNL. (2010). Catálisis ácida. Grupo de Investigación en Ingeniería Catalítica (GICIC).
# - Kilpatrick, M. (1954). Acidic and Basic Catalysis. Advances in Catalysis (pp. 241-270). https://doi.org/10.1016/s0360-0564(08)60392-2
# - Ross, J. R. (2019). How Does a Catalyst Work? Elsevier eBooks (pp. 69-89). https://doi.org/10.1016/b978-0-444-63474-0.00003-5
# - Blanco, A., & Blanco, G. (2022). Enzymes. Elsevier eBooks (pp. 165-190).  https://doi.org/10.1016/b978-0-323-91599-1.00029-8
# - Ooka, H., Huang, J., & Exner, K. S. (2021). The Sabatier Principle in Electrocatalysis: Basics, Limitations, and Extensions. Frontiers in Energy Research, 9. https://doi.org/10.3389/fenrg.2021.654460
# - Brewster, M. (2003). Combustion Mechanisms and Simplified-Kinetics Modeling of Homogeneous Energetic Solids. Theoretical and Computational Chemistry (pp. 225-294). https://doi.org/10.1016/s1380-7323(03)80029-8
# - Denbigh, K. (1981). The Principles of Chemical Equilibrium. Cambridge University Press.
# - Norwich, K. H. (2010). Le Chatelier’s principle in sensation and perception. Frontiers In Physiology, 1, 17.
# - Masel, R. I. (2001). Chemical Kinetics and Catalysis. Wiley.
# - Cornish-Bowden, A. (2012). Fundamentals of Enzyme Kinetics. Wiley-Blackwell.
# - Bartholomew, C. H. (2001). “Mechanisms of Catalyst Deactivation.” Applied Catalysis A: General, 212, 17–60.
# - Bartholomew, C. H., & Farrauto, R. J. (2006). Fundamentals of Industrial Catalytic Processes (2nd ed.). Wiley.
# - Romero, J. G. T., Sarabia-Bañuelos, P., Hernández-González, S., & Nolasco-Arizmendi, V. A. (2020). Mecanismos de desactivación de catalizadores heterogéneos. Mundo Nano. Revista Interdisciplinaria En Nanociencia y Nanotecnología, 14(26), 1e-16e.
# - Somorjai, G. A., & Li, Y. (2010). Introduction to Surface Chemistry and Catalysis (2nd ed.). Wiley.
# - Hatta, A., Jalil, A., Hassan, N., Hamid, M., Bahari, M., Azis, T., & otros. (2023). A comprehensive review on catalyst regeneration strategies. Materials Today Chemistry, 33, 101743.
# - Parlamento Europeo. (2023). Economía circular: definición, importancia y beneficios. Parlamento Europeo.
# - Del Rocío Redón de la Fuente, M. (2016). Nanopartículas catalíticas. ¿polvo mágico? Mundo Nano, 8(15), 53-90. https://doi.org/10.22201/ceiich.24485691e.2015.15.53868
# - Guibelondo, D. M. T. (2025, January 13). Catalysts: Pioneering energy-efficient chemical reactions. Pharma Features.
# - https://pharmafeatures.com/catalysts-pioneering-energy-efficient-chemical-reactions/

# %%
# Espacio para desarrollar ejercicios o ejemplos de catálisis
